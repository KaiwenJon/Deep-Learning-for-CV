# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import models

from src.resnet_yolo import resnet50
from yolo_loss import YoloLoss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = None # 'checkpoints/best_detector.pth' #'checkpoints/best_detector.pth' 
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Load pre-trained model
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
learning_rate = 0.001
num_epochs = 50
batch_size = 24

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = 'data/VOCdevkit_2007/VOC2007/JPEGImages/'
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=0)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = 'data/VOCdevkit_2007/VOC2007test/JPEGImages/'
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=0)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Set up training tools

# %%
criterion = YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
torch.cuda.empty_cache()
best_test_loss = np.inf
learning_rate = 1e-3
for epoch in range(num_epochs):
    net.train()
    
    # Update learning rate late in training
    if epoch == 30 or epoch == 40:
        learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate
    
    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))
    
    total_loss = collections.defaultdict(int)
    
    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()
        
        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()
        
        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)
    
    # evaluate the network on the test data
    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data
            
            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)
    
    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')
    
    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 50
# Learning Rate for this epoch: 0.001
# Epoch [1/50], Iter [50/209], Loss: total=28.749, reg=7.759, containing_obj=0.293, no_obj=12.986, cls=7.711
# Epoch [1/50], Iter [100/209], Loss: total=20.732, reg=7.620, containing_obj=0.322, no_obj=7.153, cls=5.636
# Epoch [1/50], Iter [150/209], Loss: total=17.534, reg=7.168, containing_obj=0.313, no_obj=5.340, cls=4.712
# Epoch [1/50], Iter [200/209], Loss: total=15.651, reg=6.781, containing_obj=0.308, no_obj=4.430, cls=4.131
# Updating best test loss: 9.47190
#
#
# Starting epoch 2 / 50
# Learning Rate for this epoch: 0.001
# Epoch [2/50], Iter [50/209], Loss: total=9.025, reg=5.173, containing_obj=0.275, no_obj=1.567, cls=2.011
# Epoch [2/50], Iter [100/209], Loss: total=8.908, reg=5.111, containing_obj=0.274, no_obj=1.546, cls=1.977
# Epoch [2/50], Iter [150/209], Loss: total=8.776, reg=5.033, containing_obj=0.273, no_obj=1.543, cls=1.929
# Epoch [2/50], Iter [200/209], Loss: total=8.546, reg=4.907, containing_obj=0.266, no_obj=1.518, cls=1.855
# Updating best test loss: 7.98393
#
#
# Starting epoch 3 / 50
# Learning Rate for this epoch: 0.001
# Epoch [3/50], Iter [50/209], Loss: total=7.963, reg=4.631, containing_obj=0.252, no_obj=1.446, cls=1.634
# Epoch [3/50], Iter [100/209], Loss: total=7.663, reg=4.442, containing_obj=0.243, no_obj=1.424, cls=1.554
# Epoch [3/50], Iter [150/209], Loss: total=7.469, reg=4.345, containing_obj=0.240, no_obj=1.387, cls=1.498
# Epoch [3/50], Iter [200/209], Loss: total=7.404, reg=4.314, containing_obj=0.238, no_obj=1.381, cls=1.471
# Updating best test loss: 7.46504
#
#
# Starting epoch 4 / 50
# Learning Rate for this epoch: 0.001
# Epoch [4/50], Iter [50/209], Loss: total=6.994, reg=4.100, containing_obj=0.232, no_obj=1.337, cls=1.325
# Epoch [4/50], Iter [100/209], Loss: total=6.831, reg=3.972, containing_obj=0.220, no_obj=1.338, cls=1.301
# Epoch [4/50], Iter [150/209], Loss: total=6.780, reg=3.965, containing_obj=0.219, no_obj=1.324, cls=1.272
# Epoch [4/50], Iter [200/209], Loss: total=6.712, reg=3.937, containing_obj=0.218, no_obj=1.308, cls=1.250
# Updating best test loss: 6.91659
#
#
# Starting epoch 5 / 50
# Learning Rate for this epoch: 0.001
# Epoch [5/50], Iter [50/209], Loss: total=6.360, reg=3.709, containing_obj=0.201, no_obj=1.293, cls=1.157
# Epoch [5/50], Iter [100/209], Loss: total=6.368, reg=3.737, containing_obj=0.209, no_obj=1.268, cls=1.154
# Epoch [5/50], Iter [150/209], Loss: total=6.378, reg=3.761, containing_obj=0.209, no_obj=1.270, cls=1.138
# Epoch [5/50], Iter [200/209], Loss: total=6.249, reg=3.694, containing_obj=0.205, no_obj=1.249, cls=1.101
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:43<00:00, 30.27it/s]
# ---class aeroplane ap 0.2849517518448045---
# ---class bicycle ap 0.33795087732281404---
# ---class bird ap 0.22440349449529604---
# ---class boat ap 0.07619109489852892---
# ---class bottle ap 0.04537659992620348---
# ---class bus ap 0.020908356119623727---
# ---class car ap 0.5061937229395916---
# ---class cat ap 0.42651178397716183---
# ---class chair ap 0.19339118521388798---
# ---class cow ap 0.013220518244315176---
# ---class diningtable ap 0.03488210818307906---
# ---class dog ap 0.08603606179548422---
# ---class horse ap 0.5137146881811708---
# ---class motorbike ap 0.3655106411905905---
# ---class person ap 0.40117558685980076---
# ---class pottedplant ap 0.0937121815072848---
# ---class sheep ap 0.06266413061302276---
# ---class sofa ap 0.0807304625568504---
# ---class train ap 0.46917387878649064---
# ---class tvmonitor ap 0.4071538895439666---
# ---map 0.23219265070999842---
# 4 [0.2849517518448045, 0.33795087732281404, 0.22440349449529604, 0.07619109489852892, 0.04537659992620348, 0.020908356119623727, 0.5061937229395916, 0.42651178397716183, 0.19339118521388798, 0.013220518244315176, 0.03488210818307906, 0.08603606179548422, 0.5137146881811708, 0.3655106411905905, 0.40117558685980076, 0.0937121815072848, 0.06266413061302276, 0.0807304625568504, 0.46917387878649064, 0.4071538895439666]
# Updating best test loss: 6.41990
#
#
# Starting epoch 6 / 50
# Learning Rate for this epoch: 0.001
# Epoch [6/50], Iter [50/209], Loss: total=5.615, reg=3.350, containing_obj=0.188, no_obj=1.174, cls=0.902
# Epoch [6/50], Iter [100/209], Loss: total=5.694, reg=3.381, containing_obj=0.192, no_obj=1.189, cls=0.932
# Epoch [6/50], Iter [150/209], Loss: total=5.826, reg=3.473, containing_obj=0.199, no_obj=1.193, cls=0.960
# Epoch [6/50], Iter [200/209], Loss: total=5.764, reg=3.430, containing_obj=0.199, no_obj=1.193, cls=0.942
# Updating best test loss: 6.35535
#
#
# Starting epoch 7 / 50
# Learning Rate for this epoch: 0.001
# Epoch [7/50], Iter [50/209], Loss: total=5.474, reg=3.244, containing_obj=0.185, no_obj=1.176, cls=0.868
# Epoch [7/50], Iter [100/209], Loss: total=5.415, reg=3.216, containing_obj=0.185, no_obj=1.161, cls=0.852
# Epoch [7/50], Iter [150/209], Loss: total=5.403, reg=3.216, containing_obj=0.185, no_obj=1.154, cls=0.848
# Epoch [7/50], Iter [200/209], Loss: total=5.422, reg=3.234, containing_obj=0.185, no_obj=1.153, cls=0.851
# Updating best test loss: 6.05375
#
#
# Starting epoch 8 / 50
# Learning Rate for this epoch: 0.001
# Epoch [8/50], Iter [50/209], Loss: total=5.108, reg=3.005, containing_obj=0.177, no_obj=1.126, cls=0.799
# Epoch [8/50], Iter [100/209], Loss: total=5.138, reg=3.049, containing_obj=0.179, no_obj=1.130, cls=0.780
# Epoch [8/50], Iter [150/209], Loss: total=5.120, reg=3.054, containing_obj=0.179, no_obj=1.128, cls=0.760
# Epoch [8/50], Iter [200/209], Loss: total=5.177, reg=3.099, containing_obj=0.181, no_obj=1.128, cls=0.769
# Updating best test loss: 5.95137
#
#
# Starting epoch 9 / 50
# Learning Rate for this epoch: 0.001
# Epoch [9/50], Iter [50/209], Loss: total=4.768, reg=2.828, containing_obj=0.171, no_obj=1.107, cls=0.662
# Epoch [9/50], Iter [100/209], Loss: total=4.926, reg=2.949, containing_obj=0.179, no_obj=1.107, cls=0.691
# Epoch [9/50], Iter [150/209], Loss: total=4.992, reg=2.992, containing_obj=0.181, no_obj=1.105, cls=0.713
# Epoch [9/50], Iter [200/209], Loss: total=4.962, reg=2.972, containing_obj=0.181, no_obj=1.102, cls=0.707
# Updating best test loss: 5.73215
#
#
# Starting epoch 10 / 50
# Learning Rate for this epoch: 0.001
# Epoch [10/50], Iter [50/209], Loss: total=4.546, reg=2.718, containing_obj=0.170, no_obj=1.046, cls=0.612
# Epoch [10/50], Iter [100/209], Loss: total=4.606, reg=2.758, containing_obj=0.170, no_obj=1.058, cls=0.620
# Epoch [10/50], Iter [150/209], Loss: total=4.674, reg=2.786, containing_obj=0.173, no_obj=1.080, cls=0.634
# Epoch [10/50], Iter [200/209], Loss: total=4.745, reg=2.837, containing_obj=0.175, no_obj=1.087, cls=0.645
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:36<00:00, 31.69it/s]
# ---class aeroplane ap 0.47633462047357433---
# ---class bicycle ap 0.558831801401398---
# ---class bird ap 0.47515008202692144---
# ---class boat ap 0.22855408784692083---
# ---class bottle ap 0.1974362410533102---
# ---class bus ap 0.4922746595245312---
# ---class car ap 0.5876955055938949---
# ---class cat ap 0.6245736824690643---
# ---class chair ap 0.287379460929156---
# ---class cow ap 0.21801667301075786---
# ---class diningtable ap 0.3412543091257223---
# ---class dog ap 0.4974213153871499---
# ---class horse ap 0.5821548687604466---
# ---class motorbike ap 0.5062004187380265---
# ---class person ap 0.5207533267191891---
# ---class pottedplant ap 0.11637723711761572---
# ---class sheep ap 0.14713948461717613---
# ---class sofa ap 0.4682925327114461---
# ---class train ap 0.6227496780086519---
# ---class tvmonitor ap 0.4197321692612255---
# ---map 0.41841610773880894---
# 9 [0.47633462047357433, 0.558831801401398, 0.47515008202692144, 0.22855408784692083, 0.1974362410533102, 0.4922746595245312, 0.5876955055938949, 0.6245736824690643, 0.287379460929156, 0.21801667301075786, 0.3412543091257223, 0.4974213153871499, 0.5821548687604466, 0.5062004187380265, 0.5207533267191891, 0.11637723711761572, 0.14713948461717613, 0.4682925327114461, 0.6227496780086519, 0.4197321692612255]
# Updating best test loss: 5.58485
#
#
# Starting epoch 11 / 50
# Learning Rate for this epoch: 0.001
# Epoch [11/50], Iter [50/209], Loss: total=4.437, reg=2.654, containing_obj=0.172, no_obj=1.057, cls=0.555
# Epoch [11/50], Iter [100/209], Loss: total=4.515, reg=2.699, containing_obj=0.173, no_obj=1.060, cls=0.583
# Epoch [11/50], Iter [150/209], Loss: total=4.509, reg=2.706, containing_obj=0.172, no_obj=1.051, cls=0.580
# Epoch [11/50], Iter [200/209], Loss: total=4.546, reg=2.734, containing_obj=0.175, no_obj=1.049, cls=0.588
# Updating best test loss: 5.54178
#
#
# Starting epoch 12 / 50
# Learning Rate for this epoch: 0.001
# Epoch [12/50], Iter [50/209], Loss: total=4.449, reg=2.684, containing_obj=0.159, no_obj=1.048, cls=0.557
# Epoch [12/50], Iter [100/209], Loss: total=4.421, reg=2.652, containing_obj=0.163, no_obj=1.042, cls=0.564
# Epoch [12/50], Iter [150/209], Loss: total=4.397, reg=2.643, containing_obj=0.164, no_obj=1.038, cls=0.552
# Epoch [12/50], Iter [200/209], Loss: total=4.390, reg=2.639, containing_obj=0.164, no_obj=1.040, cls=0.547
#
#
# Starting epoch 13 / 50
# Learning Rate for this epoch: 0.001
# Epoch [13/50], Iter [50/209], Loss: total=4.142, reg=2.476, containing_obj=0.155, no_obj=0.996, cls=0.514
# Epoch [13/50], Iter [100/209], Loss: total=4.176, reg=2.519, containing_obj=0.158, no_obj=0.995, cls=0.504
# Epoch [13/50], Iter [150/209], Loss: total=4.208, reg=2.535, containing_obj=0.160, no_obj=1.010, cls=0.504
# Epoch [13/50], Iter [200/209], Loss: total=4.272, reg=2.586, containing_obj=0.162, no_obj=1.006, cls=0.518
# Updating best test loss: 5.50421
#
#
# Starting epoch 14 / 50
# Learning Rate for this epoch: 0.001
# Epoch [14/50], Iter [50/209], Loss: total=4.219, reg=2.542, containing_obj=0.158, no_obj=1.003, cls=0.515
# Epoch [14/50], Iter [100/209], Loss: total=4.189, reg=2.526, containing_obj=0.156, no_obj=1.004, cls=0.504
# Epoch [14/50], Iter [150/209], Loss: total=4.164, reg=2.513, containing_obj=0.156, no_obj=0.998, cls=0.496
# Epoch [14/50], Iter [200/209], Loss: total=4.154, reg=2.508, containing_obj=0.158, no_obj=0.992, cls=0.495
# Updating best test loss: 5.37006
#
#
# Starting epoch 15 / 50
# Learning Rate for this epoch: 0.001
# Epoch [15/50], Iter [50/209], Loss: total=3.689, reg=2.206, containing_obj=0.139, no_obj=0.911, cls=0.432
# Epoch [15/50], Iter [100/209], Loss: total=3.872, reg=2.347, containing_obj=0.146, no_obj=0.934, cls=0.446
# Epoch [15/50], Iter [150/209], Loss: total=3.943, reg=2.382, containing_obj=0.154, no_obj=0.955, cls=0.453
# Epoch [15/50], Iter [200/209], Loss: total=3.992, reg=2.400, containing_obj=0.156, no_obj=0.971, cls=0.464
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:32<00:00, 32.41it/s]
# ---class aeroplane ap 0.3956801492275929---
# ---class bicycle ap 0.6659719582055041---
# ---class bird ap 0.4490217127577076---
# ---class boat ap 0.27384287420057063---
# ---class bottle ap 0.25728200746785507---
# ---class bus ap 0.4868995324639798---
# ---class car ap 0.6822337645558538---
# ---class cat ap 0.714270585032122---
# ---class chair ap 0.3167450720339348---
# ---class cow ap 0.3266064075262594---
# ---class diningtable ap 0.34650565271098516---
# ---class dog ap 0.591790077753767---
# ---class horse ap 0.6548972597301129---
# ---class motorbike ap 0.5306234648514746---
# ---class person ap 0.5505400039090648---
# ---class pottedplant ap 0.1873311554679063---
# ---class sheep ap 0.3129926208066688---
# ---class sofa ap 0.5138936468054482---
# ---class train ap 0.6263851298225815---
# ---class tvmonitor ap 0.5179893002730962---
# ---map 0.4700751187801243---
# 14 [0.3956801492275929, 0.6659719582055041, 0.4490217127577076, 0.27384287420057063, 0.25728200746785507, 0.4868995324639798, 0.6822337645558538, 0.714270585032122, 0.3167450720339348, 0.3266064075262594, 0.34650565271098516, 0.591790077753767, 0.6548972597301129, 0.5306234648514746, 0.5505400039090648, 0.1873311554679063, 0.3129926208066688, 0.5138936468054482, 0.6263851298225815, 0.5179893002730962]
# Updating best test loss: 5.34398
#
#
# Starting epoch 16 / 50
# Learning Rate for this epoch: 0.001
# Epoch [16/50], Iter [50/209], Loss: total=3.876, reg=2.321, containing_obj=0.149, no_obj=0.962, cls=0.444
# Epoch [16/50], Iter [100/209], Loss: total=3.880, reg=2.318, containing_obj=0.152, no_obj=0.968, cls=0.441
# Epoch [16/50], Iter [150/209], Loss: total=3.897, reg=2.338, containing_obj=0.151, no_obj=0.973, cls=0.434
# Epoch [16/50], Iter [200/209], Loss: total=3.927, reg=2.364, containing_obj=0.153, no_obj=0.971, cls=0.439
#
#
# Starting epoch 17 / 50
# Learning Rate for this epoch: 0.001
# Epoch [17/50], Iter [50/209], Loss: total=3.730, reg=2.215, containing_obj=0.150, no_obj=0.953, cls=0.412
# Epoch [17/50], Iter [100/209], Loss: total=3.680, reg=2.184, containing_obj=0.146, no_obj=0.936, cls=0.414
# Epoch [17/50], Iter [150/209], Loss: total=3.722, reg=2.226, containing_obj=0.146, no_obj=0.930, cls=0.420
# Epoch [17/50], Iter [200/209], Loss: total=3.762, reg=2.252, containing_obj=0.147, no_obj=0.940, cls=0.424
#
#
# Starting epoch 18 / 50
# Learning Rate for this epoch: 0.001
# Epoch [18/50], Iter [50/209], Loss: total=3.737, reg=2.248, containing_obj=0.147, no_obj=0.936, cls=0.406
# Epoch [18/50], Iter [100/209], Loss: total=3.710, reg=2.248, containing_obj=0.148, no_obj=0.922, cls=0.393
# Epoch [18/50], Iter [150/209], Loss: total=3.674, reg=2.215, containing_obj=0.148, no_obj=0.921, cls=0.390
# Epoch [18/50], Iter [200/209], Loss: total=3.688, reg=2.222, containing_obj=0.149, no_obj=0.927, cls=0.389
# Updating best test loss: 5.29006
#
#
# Starting epoch 19 / 50
# Learning Rate for this epoch: 0.001
# Epoch [19/50], Iter [50/209], Loss: total=3.524, reg=2.112, containing_obj=0.145, no_obj=0.901, cls=0.366
# Epoch [19/50], Iter [100/209], Loss: total=3.642, reg=2.194, containing_obj=0.148, no_obj=0.908, cls=0.392
# Epoch [19/50], Iter [150/209], Loss: total=3.651, reg=2.200, containing_obj=0.146, no_obj=0.920, cls=0.386
# Epoch [19/50], Iter [200/209], Loss: total=3.627, reg=2.184, containing_obj=0.145, no_obj=0.919, cls=0.379
# Updating best test loss: 5.23051
#
#
# Starting epoch 20 / 50
# Learning Rate for this epoch: 0.001
# Epoch [20/50], Iter [50/209], Loss: total=3.527, reg=2.089, containing_obj=0.139, no_obj=0.933, cls=0.366
# Epoch [20/50], Iter [100/209], Loss: total=3.549, reg=2.118, containing_obj=0.141, no_obj=0.929, cls=0.361
# Epoch [20/50], Iter [150/209], Loss: total=3.509, reg=2.103, containing_obj=0.141, no_obj=0.913, cls=0.352
# Epoch [20/50], Iter [200/209], Loss: total=3.541, reg=2.128, containing_obj=0.143, no_obj=0.910, cls=0.360
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:26<00:00, 33.71it/s]
# ---class aeroplane ap 0.5038868659448434---
# ---class bicycle ap 0.6476043768560824---
# ---class bird ap 0.5248825290064097---
# ---class boat ap 0.35334895904433006---
# ---class bottle ap 0.2282051068317191---
# ---class bus ap 0.61700282739121---
# ---class car ap 0.6910361999229055---
# ---class cat ap 0.7366296779896144---
# ---class chair ap 0.35023421579603153---
# ---class cow ap 0.4590093514982606---
# ---class diningtable ap 0.3404591182398111---
# ---class dog ap 0.621371567484929---
# ---class horse ap 0.6322584094949082---
# ---class motorbike ap 0.5934699929304614---
# ---class person ap 0.5571987883635191---
# ---class pottedplant ap 0.17771887370331668---
# ---class sheep ap 0.4054300702544702---
# ---class sofa ap 0.49231471432349727---
# ---class train ap 0.7033062853672345---
# ---class tvmonitor ap 0.5386188295268903---
# ---map 0.5086993379985223---
# 19 [0.5038868659448434, 0.6476043768560824, 0.5248825290064097, 0.35334895904433006, 0.2282051068317191, 0.61700282739121, 0.6910361999229055, 0.7366296779896144, 0.35023421579603153, 0.4590093514982606, 0.3404591182398111, 0.621371567484929, 0.6322584094949082, 0.5934699929304614, 0.5571987883635191, 0.17771887370331668, 0.4054300702544702, 0.49231471432349727, 0.7033062853672345, 0.5386188295268903]
#
#
# Starting epoch 21 / 50
# Learning Rate for this epoch: 0.001
# Epoch [21/50], Iter [50/209], Loss: total=3.607, reg=2.191, containing_obj=0.144, no_obj=0.917, cls=0.355
# Epoch [21/50], Iter [100/209], Loss: total=3.548, reg=2.150, containing_obj=0.144, no_obj=0.905, cls=0.349
# Epoch [21/50], Iter [150/209], Loss: total=3.469, reg=2.093, containing_obj=0.139, no_obj=0.889, cls=0.348
# Epoch [21/50], Iter [200/209], Loss: total=3.468, reg=2.096, containing_obj=0.141, no_obj=0.885, cls=0.346
#
#
# Starting epoch 22 / 50
# Learning Rate for this epoch: 0.001
# Epoch [22/50], Iter [50/209], Loss: total=3.468, reg=2.092, containing_obj=0.144, no_obj=0.885, cls=0.347
# Epoch [22/50], Iter [100/209], Loss: total=3.449, reg=2.074, containing_obj=0.142, no_obj=0.886, cls=0.347
# Epoch [22/50], Iter [150/209], Loss: total=3.465, reg=2.094, containing_obj=0.144, no_obj=0.883, cls=0.344
# Epoch [22/50], Iter [200/209], Loss: total=3.435, reg=2.071, containing_obj=0.141, no_obj=0.878, cls=0.344
#
#
# Starting epoch 23 / 50
# Learning Rate for this epoch: 0.001
# Epoch [23/50], Iter [50/209], Loss: total=3.444, reg=2.094, containing_obj=0.137, no_obj=0.881, cls=0.332
# Epoch [23/50], Iter [100/209], Loss: total=3.414, reg=2.056, containing_obj=0.139, no_obj=0.876, cls=0.342
# Epoch [23/50], Iter [150/209], Loss: total=3.348, reg=2.011, containing_obj=0.138, no_obj=0.862, cls=0.337
# Epoch [23/50], Iter [200/209], Loss: total=3.351, reg=2.013, containing_obj=0.139, no_obj=0.863, cls=0.335
# Updating best test loss: 5.20138
#
#
# Starting epoch 24 / 50
# Learning Rate for this epoch: 0.001
# Epoch [24/50], Iter [50/209], Loss: total=3.153, reg=1.879, containing_obj=0.135, no_obj=0.850, cls=0.290
# Epoch [24/50], Iter [100/209], Loss: total=3.188, reg=1.904, containing_obj=0.133, no_obj=0.852, cls=0.299
# Epoch [24/50], Iter [150/209], Loss: total=3.230, reg=1.944, containing_obj=0.136, no_obj=0.844, cls=0.305
# Epoch [24/50], Iter [200/209], Loss: total=3.255, reg=1.957, containing_obj=0.138, no_obj=0.847, cls=0.313
#
#
# Starting epoch 25 / 50
# Learning Rate for this epoch: 0.001
# Epoch [25/50], Iter [50/209], Loss: total=3.152, reg=1.869, containing_obj=0.134, no_obj=0.850, cls=0.299
# Epoch [25/50], Iter [100/209], Loss: total=3.141, reg=1.889, containing_obj=0.134, no_obj=0.819, cls=0.300
# Epoch [25/50], Iter [150/209], Loss: total=3.221, reg=1.945, containing_obj=0.139, no_obj=0.832, cls=0.306
# Epoch [25/50], Iter [200/209], Loss: total=3.202, reg=1.924, containing_obj=0.137, no_obj=0.837, cls=0.305
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:25<00:00, 34.13it/s]
# ---class aeroplane ap 0.5575499212191897---
# ---class bicycle ap 0.7038997211011069---
# ---class bird ap 0.5909954835906599---
# ---class boat ap 0.38037880304855815---
# ---class bottle ap 0.3221010336852827---
# ---class bus ap 0.6332518432473246---
# ---class car ap 0.706503399379199---
# ---class cat ap 0.7347966956280456---
# ---class chair ap 0.3960951937842845---
# ---class cow ap 0.49377302364432085---
# ---class diningtable ap 0.4400552400805498---
# ---class dog ap 0.5504287656643139---
# ---class horse ap 0.7028318694540141---
# ---class motorbike ap 0.5890986012558374---
# ---class person ap 0.6360094849409473---
# ---class pottedplant ap 0.27002134667305716---
# ---class sheep ap 0.4410565950053337---
# ---class sofa ap 0.505285389311866---
# ---class train ap 0.6963279049423374---
# ---class tvmonitor ap 0.548991980919598---
# ---map 0.5449726148287913---
# 24 [0.5575499212191897, 0.7038997211011069, 0.5909954835906599, 0.38037880304855815, 0.3221010336852827, 0.6332518432473246, 0.706503399379199, 0.7347966956280456, 0.3960951937842845, 0.49377302364432085, 0.4400552400805498, 0.5504287656643139, 0.7028318694540141, 0.5890986012558374, 0.6360094849409473, 0.27002134667305716, 0.4410565950053337, 0.505285389311866, 0.6963279049423374, 0.548991980919598]
#
#
# Starting epoch 26 / 50
# Learning Rate for this epoch: 0.001
# Epoch [26/50], Iter [50/209], Loss: total=3.104, reg=1.865, containing_obj=0.135, no_obj=0.819, cls=0.286
# Epoch [26/50], Iter [100/209], Loss: total=3.141, reg=1.891, containing_obj=0.138, no_obj=0.823, cls=0.289
# Epoch [26/50], Iter [150/209], Loss: total=3.133, reg=1.873, containing_obj=0.136, no_obj=0.830, cls=0.293
# Epoch [26/50], Iter [200/209], Loss: total=3.149, reg=1.880, containing_obj=0.136, no_obj=0.833, cls=0.300
#
#
# Starting epoch 27 / 50
# Learning Rate for this epoch: 0.001
# Epoch [27/50], Iter [50/209], Loss: total=3.048, reg=1.843, containing_obj=0.132, no_obj=0.794, cls=0.280
# Epoch [27/50], Iter [100/209], Loss: total=3.100, reg=1.879, containing_obj=0.137, no_obj=0.811, cls=0.273
# Epoch [27/50], Iter [150/209], Loss: total=3.097, reg=1.860, containing_obj=0.135, no_obj=0.822, cls=0.280
# Epoch [27/50], Iter [200/209], Loss: total=3.116, reg=1.875, containing_obj=0.134, no_obj=0.822, cls=0.285
#
#
# Starting epoch 28 / 50
# Learning Rate for this epoch: 0.001
# Epoch [28/50], Iter [50/209], Loss: total=3.137, reg=1.870, containing_obj=0.136, no_obj=0.813, cls=0.318
# Epoch [28/50], Iter [100/209], Loss: total=3.083, reg=1.844, containing_obj=0.132, no_obj=0.809, cls=0.299
# Epoch [28/50], Iter [150/209], Loss: total=3.097, reg=1.866, containing_obj=0.133, no_obj=0.811, cls=0.287
# Epoch [28/50], Iter [200/209], Loss: total=3.081, reg=1.857, containing_obj=0.131, no_obj=0.812, cls=0.280
#
#
# Starting epoch 29 / 50
# Learning Rate for this epoch: 0.001
# Epoch [29/50], Iter [50/209], Loss: total=3.163, reg=1.917, containing_obj=0.137, no_obj=0.830, cls=0.280
# Epoch [29/50], Iter [100/209], Loss: total=3.026, reg=1.814, containing_obj=0.129, no_obj=0.821, cls=0.261
# Epoch [29/50], Iter [150/209], Loss: total=3.028, reg=1.815, containing_obj=0.132, no_obj=0.816, cls=0.264
# Epoch [29/50], Iter [200/209], Loss: total=3.019, reg=1.812, containing_obj=0.132, no_obj=0.813, cls=0.263
#
#
# Starting epoch 30 / 50
# Learning Rate for this epoch: 0.001
# Epoch [30/50], Iter [50/209], Loss: total=2.866, reg=1.718, containing_obj=0.129, no_obj=0.762, cls=0.257
# Epoch [30/50], Iter [100/209], Loss: total=2.972, reg=1.790, containing_obj=0.128, no_obj=0.790, cls=0.264
# Epoch [30/50], Iter [150/209], Loss: total=2.992, reg=1.799, containing_obj=0.131, no_obj=0.795, cls=0.266
# Epoch [30/50], Iter [200/209], Loss: total=2.982, reg=1.792, containing_obj=0.130, no_obj=0.803, cls=0.258
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:24<00:00, 34.20it/s]
# ---class aeroplane ap 0.5707917681184156---
# ---class bicycle ap 0.7022614184548822---
# ---class bird ap 0.5650145795444941---
# ---class boat ap 0.3447501776501904---
# ---class bottle ap 0.27780159815077327---
# ---class bus ap 0.6222358114112301---
# ---class car ap 0.7182536526708247---
# ---class cat ap 0.6914821814775096---
# ---class chair ap 0.3367764240724726---
# ---class cow ap 0.5254180191640678---
# ---class diningtable ap 0.45460906244964294---
# ---class dog ap 0.6699148989710525---
# ---class horse ap 0.7292786933485061---
# ---class motorbike ap 0.6623752391916857---
# ---class person ap 0.6428467172251275---
# ---class pottedplant ap 0.22073759599121137---
# ---class sheep ap 0.516264717572801---
# ---class sofa ap 0.5317658125788312---
# ---class train ap 0.7489328938676981---
# ---class tvmonitor ap 0.5720927490647103---
# ---map 0.5551802005488063---
# 29 [0.5707917681184156, 0.7022614184548822, 0.5650145795444941, 0.3447501776501904, 0.27780159815077327, 0.6222358114112301, 0.7182536526708247, 0.6914821814775096, 0.3367764240724726, 0.5254180191640678, 0.45460906244964294, 0.6699148989710525, 0.7292786933485061, 0.6623752391916857, 0.6428467172251275, 0.22073759599121137, 0.516264717572801, 0.5317658125788312, 0.7489328938676981, 0.5720927490647103]
#
#
# Starting epoch 31 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [31/50], Iter [50/209], Loss: total=2.956, reg=1.848, containing_obj=0.131, no_obj=0.731, cls=0.246
# Epoch [31/50], Iter [100/209], Loss: total=2.881, reg=1.760, containing_obj=0.129, no_obj=0.753, cls=0.238
# Epoch [31/50], Iter [150/209], Loss: total=2.812, reg=1.695, containing_obj=0.125, no_obj=0.754, cls=0.238
# Epoch [31/50], Iter [200/209], Loss: total=2.755, reg=1.655, containing_obj=0.122, no_obj=0.748, cls=0.231
#
#
# Starting epoch 32 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [32/50], Iter [50/209], Loss: total=2.617, reg=1.553, containing_obj=0.117, no_obj=0.737, cls=0.210
# Epoch [32/50], Iter [100/209], Loss: total=2.628, reg=1.572, containing_obj=0.118, no_obj=0.727, cls=0.211
# Epoch [32/50], Iter [150/209], Loss: total=2.619, reg=1.572, containing_obj=0.116, no_obj=0.728, cls=0.204
# Epoch [32/50], Iter [200/209], Loss: total=2.591, reg=1.546, containing_obj=0.115, no_obj=0.725, cls=0.205
# Updating best test loss: 5.17778
#
#
# Starting epoch 33 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [33/50], Iter [50/209], Loss: total=2.440, reg=1.443, containing_obj=0.108, no_obj=0.713, cls=0.177
# Epoch [33/50], Iter [100/209], Loss: total=2.596, reg=1.583, containing_obj=0.117, no_obj=0.697, cls=0.200
# Epoch [33/50], Iter [150/209], Loss: total=2.550, reg=1.529, containing_obj=0.114, no_obj=0.706, cls=0.201
# Epoch [33/50], Iter [200/209], Loss: total=2.560, reg=1.538, containing_obj=0.116, no_obj=0.705, cls=0.200
# Updating best test loss: 5.17338
#
#
# Starting epoch 34 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [34/50], Iter [50/209], Loss: total=2.570, reg=1.514, containing_obj=0.115, no_obj=0.730, cls=0.211
# Epoch [34/50], Iter [100/209], Loss: total=2.534, reg=1.491, containing_obj=0.115, no_obj=0.722, cls=0.206
# Epoch [34/50], Iter [150/209], Loss: total=2.542, reg=1.508, containing_obj=0.117, no_obj=0.717, cls=0.199
# Epoch [34/50], Iter [200/209], Loss: total=2.528, reg=1.497, containing_obj=0.117, no_obj=0.715, cls=0.199
# Updating best test loss: 5.16794
#
#
# Starting epoch 35 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [35/50], Iter [50/209], Loss: total=2.395, reg=1.393, containing_obj=0.111, no_obj=0.707, cls=0.184
# Epoch [35/50], Iter [100/209], Loss: total=2.418, reg=1.431, containing_obj=0.115, no_obj=0.689, cls=0.184
# Epoch [35/50], Iter [150/209], Loss: total=2.440, reg=1.444, containing_obj=0.115, no_obj=0.688, cls=0.194
# Epoch [35/50], Iter [200/209], Loss: total=2.447, reg=1.449, containing_obj=0.115, no_obj=0.690, cls=0.193
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:18<00:00, 35.63it/s]
# ---class aeroplane ap 0.613726343189607---
# ---class bicycle ap 0.7217461391705172---
# ---class bird ap 0.6354426620428408---
# ---class boat ap 0.41851222357056406---
# ---class bottle ap 0.3256852466221809---
# ---class bus ap 0.6603349110723675---
# ---class car ap 0.738324720283881---
# ---class cat ap 0.7571649946441481---
# ---class chair ap 0.38392458322132617---
# ---class cow ap 0.6046080897939596---
# ---class diningtable ap 0.4790488953891891---
# ---class dog ap 0.6752471552859725---
# ---class horse ap 0.729653166879197---
# ---class motorbike ap 0.6422475118374037---
# ---class person ap 0.6547192872926314---
# ---class pottedplant ap 0.2591790289946387---
# ---class sheep ap 0.5160220339563294---
# ---class sofa ap 0.5298106529650859---
# ---class train ap 0.743530681633009---
# ---class tvmonitor ap 0.5940150754847924---
# ---map 0.5841471701664821---
# 34 [0.613726343189607, 0.7217461391705172, 0.6354426620428408, 0.41851222357056406, 0.3256852466221809, 0.6603349110723675, 0.738324720283881, 0.7571649946441481, 0.38392458322132617, 0.6046080897939596, 0.4790488953891891, 0.6752471552859725, 0.729653166879197, 0.6422475118374037, 0.6547192872926314, 0.2591790289946387, 0.5160220339563294, 0.5298106529650859, 0.743530681633009, 0.5940150754847924]
#
#
# Starting epoch 36 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [36/50], Iter [50/209], Loss: total=2.611, reg=1.577, containing_obj=0.124, no_obj=0.698, cls=0.211
# Epoch [36/50], Iter [100/209], Loss: total=2.557, reg=1.537, containing_obj=0.120, no_obj=0.706, cls=0.193
# Epoch [36/50], Iter [150/209], Loss: total=2.529, reg=1.513, containing_obj=0.118, no_obj=0.706, cls=0.192
# Epoch [36/50], Iter [200/209], Loss: total=2.487, reg=1.480, containing_obj=0.117, no_obj=0.704, cls=0.185
#
#
# Starting epoch 37 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [37/50], Iter [50/209], Loss: total=2.507, reg=1.508, containing_obj=0.114, no_obj=0.683, cls=0.201
# Epoch [37/50], Iter [100/209], Loss: total=2.479, reg=1.484, containing_obj=0.111, no_obj=0.690, cls=0.193
# Epoch [37/50], Iter [150/209], Loss: total=2.479, reg=1.482, containing_obj=0.113, no_obj=0.688, cls=0.196
# Epoch [37/50], Iter [200/209], Loss: total=2.490, reg=1.499, containing_obj=0.115, no_obj=0.685, cls=0.192
#
#
# Starting epoch 38 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [38/50], Iter [50/209], Loss: total=2.341, reg=1.380, containing_obj=0.108, no_obj=0.683, cls=0.170
# Epoch [38/50], Iter [100/209], Loss: total=2.381, reg=1.417, containing_obj=0.109, no_obj=0.671, cls=0.184
# Epoch [38/50], Iter [150/209], Loss: total=2.412, reg=1.444, containing_obj=0.112, no_obj=0.674, cls=0.182
# Epoch [38/50], Iter [200/209], Loss: total=2.417, reg=1.444, containing_obj=0.113, no_obj=0.675, cls=0.185
#
#
# Starting epoch 39 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [39/50], Iter [50/209], Loss: total=2.359, reg=1.374, containing_obj=0.114, no_obj=0.689, cls=0.182
# Epoch [39/50], Iter [100/209], Loss: total=2.362, reg=1.374, containing_obj=0.113, no_obj=0.694, cls=0.181
# Epoch [39/50], Iter [150/209], Loss: total=2.384, reg=1.404, containing_obj=0.115, no_obj=0.688, cls=0.177
# Epoch [39/50], Iter [200/209], Loss: total=2.408, reg=1.427, containing_obj=0.116, no_obj=0.684, cls=0.182
#
#
# Starting epoch 40 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [40/50], Iter [50/209], Loss: total=2.458, reg=1.499, containing_obj=0.114, no_obj=0.665, cls=0.180
# Epoch [40/50], Iter [100/209], Loss: total=2.364, reg=1.412, containing_obj=0.111, no_obj=0.665, cls=0.175
# Epoch [40/50], Iter [150/209], Loss: total=2.391, reg=1.430, containing_obj=0.113, no_obj=0.668, cls=0.181
# Epoch [40/50], Iter [200/209], Loss: total=2.414, reg=1.449, containing_obj=0.114, no_obj=0.668, cls=0.182
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:22<00:00, 34.73it/s]
# ---class aeroplane ap 0.6150570601037519---
# ---class bicycle ap 0.736078296609243---
# ---class bird ap 0.6276147213497866---
# ---class boat ap 0.39890800395609055---
# ---class bottle ap 0.308662726131397---
# ---class bus ap 0.6516964173913415---
# ---class car ap 0.7342708885367705---
# ---class cat ap 0.7519054410981061---
# ---class chair ap 0.39153344128780354---
# ---class cow ap 0.6018186881668866---
# ---class diningtable ap 0.4368766527048949---
# ---class dog ap 0.6899179358570623---
# ---class horse ap 0.7327947006552806---
# ---class motorbike ap 0.6517173541395043---
# ---class person ap 0.6606089352653428---
# ---class pottedplant ap 0.25339937539787477---
# ---class sheep ap 0.54687200535169---
# ---class sofa ap 0.538301399314451---
# ---class train ap 0.7326382842285424---
# ---class tvmonitor ap 0.6114360814304446---
# ---map 0.5836054204488133---
# 39 [0.6150570601037519, 0.736078296609243, 0.6276147213497866, 0.39890800395609055, 0.308662726131397, 0.6516964173913415, 0.7342708885367705, 0.7519054410981061, 0.39153344128780354, 0.6018186881668866, 0.4368766527048949, 0.6899179358570623, 0.7327947006552806, 0.6517173541395043, 0.6606089352653428, 0.25339937539787477, 0.54687200535169, 0.538301399314451, 0.7326382842285424, 0.6114360814304446]
# Updating best test loss: 5.15776
#
#
# Starting epoch 41 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [41/50], Iter [50/209], Loss: total=2.277, reg=1.315, containing_obj=0.102, no_obj=0.680, cls=0.180
# Epoch [41/50], Iter [100/209], Loss: total=2.316, reg=1.358, containing_obj=0.108, no_obj=0.671, cls=0.179
# Epoch [41/50], Iter [150/209], Loss: total=2.362, reg=1.395, containing_obj=0.111, no_obj=0.671, cls=0.185
# Epoch [41/50], Iter [200/209], Loss: total=2.339, reg=1.376, containing_obj=0.111, no_obj=0.674, cls=0.179
#
#
# Starting epoch 42 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [42/50], Iter [50/209], Loss: total=2.341, reg=1.409, containing_obj=0.108, no_obj=0.667, cls=0.158
# Epoch [42/50], Iter [100/209], Loss: total=2.389, reg=1.429, containing_obj=0.114, no_obj=0.667, cls=0.179
# Epoch [42/50], Iter [150/209], Loss: total=2.363, reg=1.400, containing_obj=0.111, no_obj=0.672, cls=0.179
# Epoch [42/50], Iter [200/209], Loss: total=2.380, reg=1.413, containing_obj=0.112, no_obj=0.671, cls=0.183
#
#
# Starting epoch 43 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [43/50], Iter [50/209], Loss: total=2.375, reg=1.431, containing_obj=0.115, no_obj=0.658, cls=0.171
# Epoch [43/50], Iter [100/209], Loss: total=2.300, reg=1.360, containing_obj=0.108, no_obj=0.663, cls=0.170
# Epoch [43/50], Iter [150/209], Loss: total=2.341, reg=1.386, containing_obj=0.109, no_obj=0.662, cls=0.183
# Epoch [43/50], Iter [200/209], Loss: total=2.340, reg=1.393, containing_obj=0.110, no_obj=0.660, cls=0.178
#
#
# Starting epoch 44 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [44/50], Iter [50/209], Loss: total=2.314, reg=1.368, containing_obj=0.107, no_obj=0.671, cls=0.168
# Epoch [44/50], Iter [100/209], Loss: total=2.355, reg=1.392, containing_obj=0.111, no_obj=0.674, cls=0.177
# Epoch [44/50], Iter [150/209], Loss: total=2.390, reg=1.428, containing_obj=0.113, no_obj=0.671, cls=0.177
# Epoch [44/50], Iter [200/209], Loss: total=2.363, reg=1.404, containing_obj=0.111, no_obj=0.672, cls=0.176
#
#
# Starting epoch 45 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [45/50], Iter [50/209], Loss: total=2.319, reg=1.371, containing_obj=0.112, no_obj=0.657, cls=0.180
# Epoch [45/50], Iter [100/209], Loss: total=2.286, reg=1.344, containing_obj=0.109, no_obj=0.655, cls=0.177
# Epoch [45/50], Iter [150/209], Loss: total=2.301, reg=1.360, containing_obj=0.110, no_obj=0.659, cls=0.172
# Epoch [45/50], Iter [200/209], Loss: total=2.317, reg=1.374, containing_obj=0.110, no_obj=0.659, cls=0.174
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:16<00:00, 36.35it/s]
# ---class aeroplane ap 0.6211281443769643---
# ---class bicycle ap 0.7372536677796514---
# ---class bird ap 0.6150874446978682---
# ---class boat ap 0.40633517406981484---
# ---class bottle ap 0.3069925371943858---
# ---class bus ap 0.6678484001680939---
# ---class car ap 0.7408601631629864---
# ---class cat ap 0.7539461069678812---
# ---class chair ap 0.3931784815940219---
# ---class cow ap 0.6109616134741771---
# ---class diningtable ap 0.47240206579244165---
# ---class dog ap 0.6971098243206348---
# ---class horse ap 0.7446720446637574---
# ---class motorbike ap 0.6405428712173773---
# ---class person ap 0.660442246110818---
# ---class pottedplant ap 0.26386581754119764---
# ---class sheep ap 0.5614498537738235---
# ---class sofa ap 0.5407746016704374---
# ---class train ap 0.740312189174553---
# ---class tvmonitor ap 0.5912086695568406---
# ---map 0.5883185958653863---
# 44 [0.6211281443769643, 0.7372536677796514, 0.6150874446978682, 0.40633517406981484, 0.3069925371943858, 0.6678484001680939, 0.7408601631629864, 0.7539461069678812, 0.3931784815940219, 0.6109616134741771, 0.47240206579244165, 0.6971098243206348, 0.7446720446637574, 0.6405428712173773, 0.660442246110818, 0.26386581754119764, 0.5614498537738235, 0.5407746016704374, 0.740312189174553, 0.5912086695568406]
#
#
# Starting epoch 46 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [46/50], Iter [50/209], Loss: total=2.308, reg=1.359, containing_obj=0.112, no_obj=0.668, cls=0.169
# Epoch [46/50], Iter [100/209], Loss: total=2.331, reg=1.389, containing_obj=0.113, no_obj=0.661, cls=0.168
# Epoch [46/50], Iter [150/209], Loss: total=2.357, reg=1.408, containing_obj=0.114, no_obj=0.659, cls=0.177
# Epoch [46/50], Iter [200/209], Loss: total=2.354, reg=1.399, containing_obj=0.112, no_obj=0.666, cls=0.176
#
#
# Starting epoch 47 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [47/50], Iter [50/209], Loss: total=2.375, reg=1.443, containing_obj=0.113, no_obj=0.651, cls=0.168
# Epoch [47/50], Iter [100/209], Loss: total=2.363, reg=1.421, containing_obj=0.111, no_obj=0.657, cls=0.173
# Epoch [47/50], Iter [150/209], Loss: total=2.340, reg=1.391, containing_obj=0.113, no_obj=0.660, cls=0.176
# Epoch [47/50], Iter [200/209], Loss: total=2.354, reg=1.403, containing_obj=0.113, no_obj=0.661, cls=0.177
#
#
# Starting epoch 48 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [48/50], Iter [50/209], Loss: total=2.413, reg=1.459, containing_obj=0.114, no_obj=0.670, cls=0.171
# Epoch [48/50], Iter [100/209], Loss: total=2.323, reg=1.389, containing_obj=0.109, no_obj=0.663, cls=0.163
# Epoch [48/50], Iter [150/209], Loss: total=2.358, reg=1.415, containing_obj=0.113, no_obj=0.663, cls=0.168
# Epoch [48/50], Iter [200/209], Loss: total=2.364, reg=1.414, containing_obj=0.112, no_obj=0.661, cls=0.176
#
#
# Starting epoch 49 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [49/50], Iter [50/209], Loss: total=2.229, reg=1.296, containing_obj=0.105, no_obj=0.665, cls=0.163
# Epoch [49/50], Iter [100/209], Loss: total=2.317, reg=1.372, containing_obj=0.110, no_obj=0.665, cls=0.170
# Epoch [49/50], Iter [150/209], Loss: total=2.295, reg=1.355, containing_obj=0.110, no_obj=0.663, cls=0.167
# Epoch [49/50], Iter [200/209], Loss: total=2.330, reg=1.388, containing_obj=0.113, no_obj=0.659, cls=0.171
#
#
# Starting epoch 50 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [50/50], Iter [50/209], Loss: total=2.251, reg=1.312, containing_obj=0.108, no_obj=0.664, cls=0.168
# Epoch [50/50], Iter [100/209], Loss: total=2.268, reg=1.322, containing_obj=0.107, no_obj=0.666, cls=0.172
# Epoch [50/50], Iter [150/209], Loss: total=2.267, reg=1.326, containing_obj=0.108, no_obj=0.665, cls=0.168
# Epoch [50/50], Iter [200/209], Loss: total=2.268, reg=1.331, containing_obj=0.108, no_obj=0.661, cls=0.169
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:15<00:00, 36.51it/s]
# ---class aeroplane ap 0.6042379241583355---
# ---class bicycle ap 0.7412891483698962---
# ---class bird ap 0.6068759198452227---
# ---class boat ap 0.420582564085235---
# ---class bottle ap 0.3067761953392305---
# ---class bus ap 0.6597726434078612---
# ---class car ap 0.7460358946458394---
# ---class cat ap 0.7613771775178448---
# ---class chair ap 0.3941207410282694---
# ---class cow ap 0.6084058677613855---
# ---class diningtable ap 0.4852458565766264---
# ---class dog ap 0.7087723886555886---
# ---class horse ap 0.7459537507767022---
# ---class motorbike ap 0.6411040561899802---
# ---class person ap 0.6547353743060921---
# ---class pottedplant ap 0.26631898382740454---
# ---class sheep ap 0.5467777730171356---
# ---class sofa ap 0.550104101109355---
# ---class train ap 0.7474352441097079---
# ---class tvmonitor ap 0.6145694000612063---
# ---map 0.5905245502394459---
# 49 [0.6042379241583355, 0.7412891483698962, 0.6068759198452227, 0.420582564085235, 0.3067761953392305, 0.6597726434078612, 0.7460358946458394, 0.7613771775178448, 0.3941207410282694, 0.6084058677613855, 0.4852458565766264, 0.7087723886555886, 0.7459537507767022, 0.6411040561899802, 0.6547353743060921, 0.26631898382740454, 0.5467777730171356, 0.550104101109355, 0.7474352441097079, 0.6145694000612063]

# %% [markdown]
# # View example predictions

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:16<00:00, 36.37it/s]
# ---class aeroplane ap 0.6042379241583355---
# ---class bicycle ap 0.7412891483698962---
# ---class bird ap 0.6068759198452227---
# ---class boat ap 0.420582564085235---
# ---class bottle ap 0.3067761953392305---
# ---class bus ap 0.6597726434078612---
# ---class car ap 0.7460358946458394---
# ---class cat ap 0.7613771775178448---
# ---class chair ap 0.3941207410282694---
# ---class cow ap 0.6084058677613855---
# ---class diningtable ap 0.4852458565766264---
# ---class dog ap 0.7087723886555886---
# ---class horse ap 0.7459537507767022---
# ---class motorbike ap 0.6411040561899802---
# ---class person ap 0.6547353743060921---
# ---class pottedplant ap 0.26631898382740454---
# ---class sheep ap 0.5467777730171356---
# ---class sofa ap 0.550104101109355---
# ---class train ap 0.7474352441097079---
# ---class tvmonitor ap 0.6145694000612063---
# ---map 0.5905245502394459---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['./checkpoints/detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# Loading saved network from ./checkpoints/detector_epoch_5.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:35<00:00, 31.91it/s]
# ---class aeroplane ap 0.2849517518448045---
# ---class bicycle ap 0.33795087732281404---
# ---class bird ap 0.22440349449529604---
# ---class boat ap 0.07619109489852892---
# ---class bottle ap 0.04537659992620348---
# ---class bus ap 0.020908356119623727---
# ---class car ap 0.5061937229395916---
# ---class cat ap 0.42651178397716183---
# ---class chair ap 0.19339118521388798---
# ---class cow ap 0.013220518244315176---
# ---class diningtable ap 0.03488210818307906---
# ---class dog ap 0.08603606179548422---
# ---class horse ap 0.5137146881811708---
# ---class motorbike ap 0.3655106411905905---
# ---class person ap 0.40117558685980076---
# ---class pottedplant ap 0.0937121815072848---
# ---class sheep ap 0.06266413061302276---
# ---class sofa ap 0.0807304625568504---
# ---class train ap 0.46917387878649064---
# ---class tvmonitor ap 0.4071538895439666---
# ---map 0.23219265070999842---
# Loading saved network from ./checkpoints/detector_epoch_10.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:33<00:00, 32.22it/s]
# ---class aeroplane ap 0.47633462047357433---
# ---class bicycle ap 0.558831801401398---
# ---class bird ap 0.47515008202692144---
# ---class boat ap 0.22855408784692083---
# ---class bottle ap 0.1974362410533102---
# ---class bus ap 0.4922746595245312---
# ---class car ap 0.5876955055938949---
# ---class cat ap 0.6245736824690643---
# ---class chair ap 0.287379460929156---
# ---class cow ap 0.21801667301075786---
# ---class diningtable ap 0.3412543091257223---
# ---class dog ap 0.4974213153871499---
# ---class horse ap 0.5821548687604466---
# ---class motorbike ap 0.5062004187380265---
# ---class person ap 0.5207533267191891---
# ---class pottedplant ap 0.11637723711761572---
# ---class sheep ap 0.14713948461717613---
# ---class sofa ap 0.4682925327114461---
# ---class train ap 0.6227496780086519---
# ---class tvmonitor ap 0.4197321692612255---
# ---map 0.41841610773880894---
# Loading saved network from ./checkpoints/detector_epoch_20.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:25<00:00, 34.13it/s]
# ---class aeroplane ap 0.5038868659448434---
# ---class bicycle ap 0.6476043768560824---
# ---class bird ap 0.5248825290064097---
# ---class boat ap 0.35334895904433006---
# ---class bottle ap 0.2282051068317191---
# ---class bus ap 0.61700282739121---
# ---class car ap 0.6910361999229055---
# ---class cat ap 0.7366296779896144---
# ---class chair ap 0.35023421579603153---
# ---class cow ap 0.4590093514982606---
# ---class diningtable ap 0.3404591182398111---
# ---class dog ap 0.621371567484929---
# ---class horse ap 0.6322584094949082---
# ---class motorbike ap 0.5934699929304614---
# ---class person ap 0.5571987883635191---
# ---class pottedplant ap 0.17771887370331668---
# ---class sheep ap 0.4054300702544702---
# ---class sofa ap 0.49231471432349727---
# ---class train ap 0.7033062853672345---
# ---class tvmonitor ap 0.5386188295268903---
# ---map 0.5086993379985223---
# Loading saved network from ./checkpoints/detector_epoch_30.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:22<00:00, 34.73it/s]
# ---class aeroplane ap 0.5707917681184156---
# ---class bicycle ap 0.7022614184548822---
# ---class bird ap 0.5650145795444941---
# ---class boat ap 0.3447501776501904---
# ---class bottle ap 0.27780159815077327---
# ---class bus ap 0.6222358114112301---
# ---class car ap 0.7182536526708247---
# ---class cat ap 0.6914821814775096---
# ---class chair ap 0.3367764240724726---
# ---class cow ap 0.5254180191640678---
# ---class diningtable ap 0.45460906244964294---
# ---class dog ap 0.6699148989710525---
# ---class horse ap 0.7292786933485061---
# ---class motorbike ap 0.6623752391916857---
# ---class person ap 0.6428467172251275---
# ---class pottedplant ap 0.22073759599121137---
# ---class sheep ap 0.516264717572801---
# ---class sofa ap 0.5317658125788312---
# ---class train ap 0.7489328938676981---
# ---class tvmonitor ap 0.5720927490647103---
# ---map 0.5551802005488063---
# Loading saved network from ./checkpoints/detector_epoch_40.pth
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:19<00:00, 35.51it/s]
# ---class aeroplane ap 0.6150570601037519---
# ---class bicycle ap 0.736078296609243---
# ---class bird ap 0.6276147213497866---
# ---class boat ap 0.39890800395609055---
# ---class bottle ap 0.308662726131397---
# ---class bus ap 0.6516964173913415---
# ---class car ap 0.7342708885367705---
# ---class cat ap 0.7519054410981061---
# ---class chair ap 0.39153344128780354---
# ---class cow ap 0.6018186881668866---
# ---class diningtable ap 0.4368766527048949---
# ---class dog ap 0.6899179358570623---
# ---class horse ap 0.7327947006552806---
# ---class motorbike ap 0.6517173541395043---
# ---class person ap 0.6606089352653428---
# ---class pottedplant ap 0.25339937539787477---
# ---class sheep ap 0.54687200535169---
# ---class sofa ap 0.538301399314451---
# ---class train ap 0.7326382842285424---
# ---class tvmonitor ap 0.6114360814304446---
# ---map 0.5836054204488133---
# Loading saved network from detector.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/tmp/ipykernel_30919/3117782976.py in <module>
#       3     print('Loading saved network from {}'.format(load_network_path))
#       4     net_loaded =  resnet50().to(device)
# ----> 5     net_loaded.load_state_dict(torch.load(load_network_path))
#       6     evaluate(net_loaded, test_dataset_file=annotation_file_test, img_root=file_root_test)
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     769         pickle_load_args['encoding'] = 'utf-8'
#     770
# --> 771     with _open_file_like(f, 'rb') as opened_file:
#     772         if _is_zipfile(opened_file):
#     773             # The zipfile reader is going to advance the current file position.
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     268 def _open_file_like(name_or_buffer, mode):
#     269     if _is_path(name_or_buffer):
# --> 270         return _open_file(name_or_buffer, mode)
#     271     else:
#     272         if 'w' in mode:
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     249 class _open_file(_opener):
#     250     def __init__(self, name, mode):
# --> 251         super(_open_file, self).__init__(open(name, mode))
#     252
#     253     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'detector.pth'

# %%
output_submission_csv('my_new_solution.csv', test_aps)
